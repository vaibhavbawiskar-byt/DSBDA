# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavbawiskar-byt/DSBDA/blob/main/DSBDA_MOCK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("/content/Demo Marks.xlsx")

# %%
df.head()
# Out:
#    Roll no            Name of Student  \
# 0        1          RAVAL MEET MAHESH
# 1        2      HUMBE BHAKTI RAJENDRA
# 2        3  MARATHE SANSKRUTI JAGDISH
# 3        4      THAKARE MRUNALI VINOD
# 4        5    BHONGALE OMKAR MADHUKAR
#
#    Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                         1131        NaN        29.0
# 1                                         1107  79.071429        29.0
# 2                                          995  71.071429        27.0
# 3                                         1077  76.928571        28.0
# 4                                         1064  76.000000        28.0
#
#          %.1  50% maks of Previous Year SPPU Result  50% Marks of Unit Test 1  \
# 0  96.666667                                   44.0                      41.0
# 1  96.666667                                   42.0                      41.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 10 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Roll no                                      74 non-null     int64
#  1   Name of Student                              74 non-null     object
#  2   Previous Year SPPU Total Marks out of  1400  74 non-null     int64
#  3   %                                            71 non-null     float64
#  4   UT 1 Marks                                   70 non-null     float64
#  5   %.1                                          69 non-null     float64
#  6   50% maks of Previous Year SPPU Result        71 non-null     float64
#  7   50% Marks of Unit Test 1                     72 non-null     float64
#  8   Total 100%                                   72 non-null     float64
# ...

# %%
display(df.describe())
# Out:
#          Roll no  Previous Year SPPU Total Marks out of  1400          %  \
# count  74.000000                                    74.000000  71.000000
# mean   37.500000                                   951.567568  68.508048
# std    21.505813                                   141.310024   9.196380
# min     1.000000                                   542.000000  43.428571
# 25%    19.250000                                   880.000000  63.607143
# 50%    37.500000                                   970.000000  69.357143
# 75%    55.750000                                  1059.750000  75.678571
# max    74.000000                                  1203.000000  85.928571
#
#        UT 1 Marks        %.1  50% maks of Previous Year SPPU Result  \
# count   70.000000  69.000000                              71.000000
# mean    23.714286  79.371981                              34.068410
# std      4.848854  16.050119                               6.517295
# ...

# %%
display(df.dtypes)
# Out:
# Roll no                                          int64
# Name of Student                                 object
# Previous Year SPPU Total Marks out of  1400      int64
# %                                              float64
# UT 1 Marks                                     float64
# %.1                                            float64
# 50% maks of Previous Year SPPU Result          float64
# 50% Marks of Unit Test 1                       float64
# Total 100%                                     float64
# Gender                                          object
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['Roll no', 'Name of Student',
#        'Previous Year SPPU Total Marks out of  1400', '%', 'UT 1 Marks', '%.1',
#        '50% maks of Previous Year SPPU Result', '50% Marks of Unit Test 1',
#        'Total 100%', 'Gender '],
#       dtype='object')

# %%
print(df["UT 1 Marks"].mean)
# Out:
# <bound method Series.mean of 0     29.0
# 1     29.0
# 2     27.0
# 3     28.0
# 4     28.0
#       ...
# 69    13.0
# 70     4.0
# 71    26.0
# 72    18.0
# 73     NaN
# Name: UT 1 Marks, Length: 74, dtype: float64>

# %%
print(df["Previous Year SPPU Total Marks out of  1400"].mean)
# Out:
# <bound method Series.mean of 0     1131
# 1     1107
# 2      995
# 3     1077
# 4     1064
#       ...
# 69     725
# 70     756
# 71     608
# 72     542
# 73     646
# Name: Previous Year SPPU Total Marks out of  1400, Length: 74, dtype: int64>

# %%
df.isnull()
# Out:
#     Roll no  Name of Student  Previous Year SPPU Total Marks out of  1400  \
# 0     False            False                                        False
# 1     False            False                                        False
# 2     False            False                                        False
# 3     False            False                                        False
# 4     False            False                                        False
# ..      ...              ...                                          ...
# 69    False            False                                        False
# 70    False            False                                        False
# 71    False            False                                        False
# 72    False            False                                        False
# 73    False            False                                        False
#
#         %  UT 1 Marks    %.1  50% maks of Previous Year SPPU Result  \
# ...

# %%
df.notnull()
# Out:
#     Roll no  Name of Student  Previous Year SPPU Total Marks out of  1400  \
# 0      True             True                                         True
# 1      True             True                                         True
# 2      True             True                                         True
# 3      True             True                                         True
# 4      True             True                                         True
# ..      ...              ...                                          ...
# 69     True             True                                         True
# 70     True             True                                         True
# 71     True             True                                         True
# 72     True             True                                         True
# 73     True             True                                         True
#
#         %  UT 1 Marks    %.1  50% maks of Previous Year SPPU Result  \
# ...

# %%
print(df.columns.tolist)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Roll no', 'Name of Student',
#        'Previous Year SPPU Total Marks out of  1400', '%', 'UT 1 Marks', '%.1',
#        '50% maks of Previous Year SPPU Result', '50% Marks of Unit Test 1',
#        'Total 100%', 'Gender '],
#       dtype='object')>

# %%
print(df.isnull().sum())
# Out:
# Roll no                                        0
# Name of Student                                0
# Previous Year SPPU Total Marks out of  1400    0
# %                                              3
# UT 1 Marks                                     4
# %.1                                            5
# 50% maks of Previous Year SPPU Result          3
# 50% Marks of Unit Test 1                       2
# Total 100%                                     2
# Gender                                         0
# dtype: int64

# %%
print(df.max)
# Out:
# <bound method DataFrame.max of     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131        NaN        29.0
# 1                                          1107  79.071429        29.0
# 2                                           995  71.071429        27.0
# 3                                          1077  76.928571        28.0
# 4                                          1064  76.000000        28.0
# ...
